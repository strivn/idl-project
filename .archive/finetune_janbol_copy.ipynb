# %%
import sys 
import os
# Append paths for the src folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# sys.path.append(os.path.abspath(os.path.join(os.getcwd(), 'idl-project')))

# %%
# Additional imports 
from src.model import load_fo_model
from src.data import load_flan_dataset
from src.utils import DEVICE, CACHE_DIR
# Out:
# Using device: cuda

# %%
import pandas as pd
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
import wandb

# %% [markdown]
# # SCALING to LARGER FLAN

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, Trainer, TrainingArguments
import torch
from datasets import load_dataset

# Configuration
batch_size = 8
model_name = "EleutherAI/pythia-160m"
total_examples = 378_000_000  # Total examples in FLAN dataset
train_ratio = 0.9
val_ratio = 0.05
test_ratio = 0.05

# Load dataset and model
dataset = load_dataset("Open-Orca/FLAN", split="train", streaming=True)
model = AutoModelForCausalLM.from_pretrained(model_name).to(DEVICE)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Configure tokenizer properly
tokenizer.pad_token = tokenizer.eos_token

def preprocess_forward(example):
    combined_text = f"{example['inputs']}\n{example['targets']}{tokenizer.eos_token}"
    tokenized = tokenizer(
        combined_text,
        truncation=True,
        max_length=768,
        padding="max_length",
        return_tensors="pt"
    )
    input_ids = tokenized["input_ids"][0]
    labels = input_ids.clone()
    labels[:-1] = input_ids[1:]
    labels[input_ids == tokenizer.pad_token_id] = -100
    return {"input_ids": input_ids, "labels": labels}
# Out:
# Resolving data files:   0%|          | 0/2167 [00:00<?, ?it/s]

# %%
# Define test prompts
test_prompts = [
    "Who is Barack Obama?",
    "What is Carnegie Mellon University?",
    "Classify this restaurant review sentiment: 'The food was absolutely delicious but the service was extremely slow and the waiter seemed uninterested in helping us.'",
    "Compare and contrast Carnegie Mellon University's Computer Science and Information Systems programs in terms of research focus and career outcomes.",
    "Summarize in one sentence: Dr. Sarah Chen, lead scientist on the mission, called it 'the most significant discovery in the history of space exploration.' The finding suggests that Mars once had a much more hospitable environment with liquid water and possibly a thicker atmosphere. The agency plans to send a sample return mission within the next five years to bring these fossils back to Earth for more detailed analysis. This discovery has profound implications for our understanding of how life might develop throughout the universe."
]


for test_input_string in test_prompts:
    inputs = tokenizer(test_input_string, return_tensors="pt").to(DEVICE)
    # print(tokens[0])
    tokens = model.generate(**inputs, max_length=150, pad_token_id=tokenizer.eos_token_id)
    print("Without sampling: " + tokenizer.decode(tokens[0]))
    
    print("---------------")
    tokens = model.generate(**inputs, max_length=150, pad_token_id=tokenizer.eos_token_id, do_sample=True)
    print("With sampling   : " + tokenizer.decode(tokens[0]))
    
    print("\n===============")
# Out:
# Without sampling: Who is Barack Obama?
#
# The president is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the people. He is a man of the
# ---------------
# With sampling   : Who is Barack Obama? I didn't care about him. Here's the thing, he was all sorts of crap. He's about as bad or worse as this piece goes. Here's the fact that we're all going to hear all of this and say, "Wow, this is actually great."
#
# "It's really not," the president has said. "We believe in Obama." But it's not like he ever got to say any more on issues like this before. If you get a president who is willing to say everything, it usually just means that he is willing to say what he wants to say. "OK, this is one thing." But this is the reality: The president of the United States, and all of
#
# ===============
# Without sampling: What is Carnegie Mellon University?
#
# The Carnegie Mellon University is a public university in the United States. It is the largest university in the world, with more than 1,000,000 students. It is the largest university in the world, with more than 1,000,000 students.
#
# The university is a member of the American Association for the Advancement of Science, and the American Association for the Advancement of Education.
#
# The university is a member of the American Association for the Advancement of Education.
#
# The university is a member of the American Association for the Advancement of Education.
#
# The university is a member of the American Association for the Advancement of Education.
#
# The university is a
# ---------------
# With sampling   : What is Carnegie Mellon University? What is Carnegie Mellon University in New York’s?
#
# So, what would a small university go through to bring in something as complex as an Internet to the world? If it was designed for mass media and broadcast, what would it have to do for communications with the world’s largest Internet conglomerate for any form of news?
#
# If a smaller college can bring in a smaller audience (at least that’s the opinion of one of the most influential professors in the world); what would it have to do at a major Internet university? How many, in what industries would have they made a mistake and why? How many, in what industries will the company be able to gain more revenue
#
# ===============
# Without sampling: Classify this restaurant review sentiment: 'The food was absolutely delicious but the service was extremely slow and the waiter seemed uninterested in helping us.'
#
# The restaurant was a small, well-appointed restaurant with a large, well-appointed dining room. The restaurant was a small, well-appointed restaurant with a large, well-appointed dining room. The restaurant was a small, well-appointed restaurant with a large, well-appointed dining room. The restaurant was a small, well-appointed restaurant with a large, well-appointed dining room. The restaurant was a small, well-appointed restaurant with a large, well-appointed dining room. The restaurant was a small, well-appointed restaurant with a large, well-appointed dining room
# ---------------
# With sampling   : Classify this restaurant review sentiment: 'The food was absolutely delicious but the service was extremely slow and the waiter seemed uninterested in helping us.'
#
# 'It was great that the place was open,' said the staff member. 'The food must be so fresh.'
#
# The restaurant was run in a traditional French restaurant that was known at the time as Gare des Fébrils ( 'gare des fruits' ).
#
# It did not have a bar, but it was in very good condition, being painted green. A few windows were barred on the second floor with a curtain made to resemble a small screen projector. The restaurant was located at 'Nespere de la Rue', a small, old-fashioned strip
#
# ===============
# Without sampling: Compare and contrast Carnegie Mellon University's Computer Science and Information Systems programs in terms of research focus and career outcomes.
#
# The program is designed to provide a comprehensive and comprehensive understanding of the computer science and information systems industry. The program is designed to provide a comprehensive and comprehensive understanding of the computer science and information systems industry. The program is designed to provide a comprehensive and comprehensive understanding of the computer science and information systems industry.
#
# The program is designed to provide a comprehensive and comprehensive understanding of the computer science and information systems industry. The program is designed to provide a comprehensive and comprehensive understanding of the computer science and information systems industry.
#
# The program is designed to provide a comprehensive and comprehensive understanding of the computer science and information systems industry. The
# ---------------
# With sampling   : Compare and contrast Carnegie Mellon University's Computer Science and Information Systems programs in terms of research focus and career outcomes. Most students work in the same field for years and in many cases they don't achieve the same things, or they are unable to do them because they don't have enough time left to learn. To make sure that they have the skills necessary.
#
# Students working with a group can learn through the same strategies they use. The group is generally more focused on learning and not on teaching. The group's strengths in computer programs are often those that have been used at different times and for different fields in various ways. Working with a group means that all members get to learn the same way regardless if it is to become a better person.
#
# ===============
# Without sampling: Summarize in one sentence: Dr. Sarah Chen, lead scientist on the mission, called it 'the most significant discovery in the history of space exploration.' The finding suggests that Mars once had a much more hospitable environment with liquid water and possibly a thicker atmosphere. The agency plans to send a sample return mission within the next five years to bring these fossils back to Earth for more detailed analysis. This discovery has profound implications for our understanding of how life might develop throughout the universe.
#
# The discovery of the first human-made spacecraft, the Apollo 11 spacecraft, is a major milestone in the history of space exploration. The first human-made spacecraft, the Apollo 11 spacecraft, was launched in December 1969. The spacecraft was designed to carry
# ---------------
# With sampling   : Summarize in one sentence: Dr. Sarah Chen, lead scientist on the mission, called it 'the most significant discovery in the history of space exploration.' The finding suggests that Mars once had a much more hospitable environment with liquid water and possibly a thicker atmosphere. The agency plans to send a sample return mission within the next five years to bring these fossils back to Earth for more detailed analysis. This discovery has profound implications for our understanding of how life might develop throughout the universe. The first known detection of carbon dioxide in the Martian mantle has been made in 1990 at a depth of 2 million kilometres. It is the first detection of methane in the Martian atmosphere and thus the most important one from a scientific study. Carbon dioxide will be
#
# ===============

# %%
# Shuffle and split before preprocessing
shuffled = dataset.shuffle(seed=42, buffer_size=100_000)

# Calculate split sizes
train_size = int(total_examples * train_ratio)
val_size = int(total_examples * val_ratio)
test_size = int(total_examples * test_ratio)

# Create splits
train_raw = shuffled.take(train_size)
remaining = shuffled.skip(train_size)
val_raw = remaining.take(val_size)
test_raw = remaining.skip(val_size).take(test_size)

# Preprocess each split
tokenized_train = train_raw.map(preprocess_forward, batched=False)
tokenized_val = val_raw.map(preprocess_forward, batched=False)
tokenized_test = test_raw.map(preprocess_forward, batched=False)

# Training configuration
training_args = TrainingArguments(
    output_dir="./pythia-finetuned",
    evaluation_strategy="steps",
    eval_steps=500,
    learning_rate=1e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    max_steps=10_000,  # Required for streaming datasets
    weight_decay=0.01,
    save_total_limit=2,
    save_steps=1000,
    logging_dir="./logs",
    logging_steps=100,
    gradient_accumulation_steps=2,
    fp16=True,
    report_to="none",
    push_to_hub=False
)

# Initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    tokenizer=tokenizer,
)

# Start training
trainer.train()

# Save final model
trainer.save_model("./pythia-finetuned-final")
tokenizer.save_pretrained("./pythia-finetuned-final")
# Out:
# /jet/home/iwiryadi/.local/lib/python3.10/site-packages/transformers/training_args.py:1611: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /var/tmp/ipykernel_61997/3659866299.py:41: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
#     <div>
#
#       <progress value='501' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  501/10000 02:53 < 54:53, 2.88 it/s, Epoch 0.05/9223372036854775807]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 50
#      41 trainer = Trainer(
#      42     model=model,
#      43     args=training_args,
#    (...)
#      46     tokenizer=tokenizer,
#      47 )
#      49 # Start training
# ---> 50 trainer.train()
#      52 # Save final model
#      53 trainer.save_model("./pythia-finetuned-final")
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:2245, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243         hf_hub_utils.enable_progress_bars()
#    2244 else:
# -> 2245     return inner_training_loop(
#    2246         args=args,
#    2247         resume_from_checkpoint=resume_from_checkpoint,
#    2248         trial=trial,
#    2249         ignore_keys_for_eval=ignore_keys_for_eval,
#    2250     )
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:2620, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2618     self.state.epoch = epoch + (step + 1 + steps_skipped) / steps_in_epoch
#    2619     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 2620     self._maybe_log_save_evaluate(
#    2621         tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time
#    2622     )
#    2623 else:
#    2624     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:3093, in Trainer._maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time)
#    3091 metrics = None
#    3092 if self.control.should_evaluate:
# -> 3093     metrics = self._evaluate(trial, ignore_keys_for_eval)
#    3094     is_new_best_metric = self._determine_best_metric(metrics=metrics, trial=trial)
#    3096     if self.args.save_strategy == SaveStrategy.BEST:
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:3047, in Trainer._evaluate(self, trial, ignore_keys_for_eval, skip_scheduler)
#    3046 def _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler=False):
# -> 3047     metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    3048     self._report_to_hp_search(trial, self.state.global_step, metrics)
#    3050     # Run delayed LR scheduler now that metrics are populated
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:4136, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    4133 start_time = time.time()
#    4135 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 4136 output = eval_loop(
#    4137     eval_dataloader,
#    4138     description="Evaluation",
#    4139     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    4140     # self.args.prediction_loss_only
#    4141     prediction_loss_only=True if self.compute_metrics is None else None,
#    4142     ignore_keys=ignore_keys,
#    4143     metric_key_prefix=metric_key_prefix,
#    4144 )
#    4146 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    4147 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:4320, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    4317 observed_num_examples = 0
#    4319 # Main evaluation loop
# -> 4320 for step, inputs in enumerate(dataloader):
#    4321     # Update the observed num examples
#    4322     observed_batch_size = find_batch_size(inputs)
#    4323     if observed_batch_size is not None:
#
# File ~/.local/lib/python3.10/site-packages/accelerate/data_loader.py:858, in DataLoaderDispatcher.__iter__(self)
#     856 self._stop_iteration = False
#     857 first_batch = None
# --> 858 next_batch, next_batch_info = self._fetch_batches(main_iterator)
#     859 batch_index = 0
#     860 while not stop_iteration:
#
# File ~/.local/lib/python3.10/site-packages/accelerate/data_loader.py:812, in DataLoaderDispatcher._fetch_batches(self, iterator)
#     810     for _ in range(self.state.num_processes):
#     811         self._update_state_dict()
# --> 812         batches.append(next(iterator))
#     813 try:
#     814     batch = concatenate(batches, dim=0)
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:33, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      31 for _ in possibly_batched_index:
#      32     try:
# ---> 33         data.append(next(self.dataset_iter))
#      34     except StopIteration:
#      35         self.ended = True
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:2266, in IterableDataset.__iter__(self)
#    2263         yield formatter.format_row(pa_table)
#    2264     return
# -> 2266 for key, example in ex_iterable:
#    2267     # no need to format thanks to FormattedExamplesIterable
#    2268     yield example
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1084, in MappedExamplesIterable.__iter__(self)
#    1082         yield key, formatter.format_row(pa_table)
#    1083 else:
# -> 1084     yield from self._iter()
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1263, in MappedExamplesIterable._iter(self)
#    1257 if self.batched:
#    1258     outputs = (
#    1259         (key, transformed_example)
#    1260         for key, transformed_batch in outputs
#    1261         for transformed_example in _batch_to_examples(transformed_batch)
#    1262     )
# -> 1263 for key, transformed_example in outputs:
#    1264     if self._state_dict and self._state_dict["previous_state"] is not None:
#    1265         self._state_dict["num_examples_since_previous_state"] += 1
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1244, in MappedExamplesIterable._iter.<locals>.iter_outputs()
#    1242         self._state_dict["num_examples_since_previous_state"] = 0
#    1243         self._state_dict["previous_state_example_idx"] = current_idx
# -> 1244 for i, key_example in inputs_iterator:
#    1245     if self._state_dict:
#    1246         if not self.batched:
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1133, in MappedExamplesIterable._iter.<locals>.iter_inputs()
#    1131 def iter_inputs():
#    1132     nonlocal current_idx
# -> 1133     for key, example in iterator:
#    1134         # If not batched, we can apply the transform and yield the example directly
#    1135         # first copy the example, since we might drop some keys
#    1136         example = dict(example)
#    1137         # no need to do formatting here
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1866, in FormattedExamplesIterable.__iter__(self)
#    1860 else:
#    1861     format_dict = (
#    1862         formatter.recursive_tensorize
#    1863         if isinstance(formatter, TensorFormatter)
#    1864         else None  # cast in case features is None
#    1865     )
# -> 1866     for key, example in self.ex_iterable:
#    1867         # don't apply feature types if already applied by ex_iterable (e.g. in case of chained with_format)
#    1868         if self.features and not self.ex_iterable.is_typed:
#    1869             example = _apply_feature_types_on_example(
#    1870                 example, self.features, token_per_repo_id=self.token_per_repo_id
#    1871             )
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1722, in TakeExamplesIterable.__iter__(self)
#    1720 def __iter__(self):
#    1721     ex_iterable_num_taken = self._state_dict["num_taken"] if self._state_dict else 0
# -> 1722     for key_example in islice(self.ex_iterable, self.n - ex_iterable_num_taken):
#    1723         if self._state_dict:
#    1724             self._state_dict["num_taken"] += 1
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1600, in SkipExamplesIterable.__iter__(self)
#    1598 if self._state_dict:
#    1599     self._state_dict["skipped"] = True
# -> 1600 yield from islice(self.ex_iterable, ex_iterable_idx_start, None)
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:1535, in BufferShuffledExamplesIterable.__iter__(self)
#    1533 # this is the shuffle buffer that we keep in memory
#    1534 mem_buffer = []
# -> 1535 for x in self.ex_iterable:
#    1536     if len(mem_buffer) == buffer_size:  # if the buffer is full, pick and example from it
#    1537         i = next(indices_iterator)
#
# File ~/.local/lib/python3.10/site-packages/datasets/iterable_dataset.py:374, in ShuffledDataSourcesArrowExamplesIterable.__iter__(self)
#     372 shard_example_idx_start = self._state_dict["shard_example_idx"] if self._state_dict else 0
#     373 shard_example_idx = 0
# --> 374 for key, pa_table in self.generate_tables_fn(**gen_kwags):
#     375     if shard_example_idx + len(pa_table) <= shard_example_idx_start:
#     376         shard_example_idx += len(pa_table)
#
# File ~/.local/lib/python3.10/site-packages/datasets/packaged_modules/parquet/parquet.py:93, in Parquet._generate_tables(self, files)
#      91 batch_size = self.config.batch_size or parquet_fragment.row_groups[0].num_rows
#      92 try:
# ---> 93     for batch_idx, record_batch in enumerate(
#      94         parquet_fragment.to_batches(
#      95             batch_size=batch_size,
#      96             columns=self.config.columns,
#      97             filter=filter_expr,
#      98             batch_readahead=0,
#      99             fragment_readahead=0,
#     100         )
#     101     ):
#     102         pa_table = pa.Table.from_batches([record_batch])
#     103         # Uncomment for debugging (will print the Arrow table size and elements)
#     104         # logger.warning(f"pa_table: {pa_table} num rows: {pa_table.num_rows}")
#     105         # logger.warning('\n'.join(str(pa_table.slice(i, 1).to_pydict()) for i in range(pa_table.num_rows)))
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/_dataset.pyx:3830, in _iterator()
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/_dataset.pyx:3439, in pyarrow._dataset.TaggedRecordBatchIterator.__next__()
#
# File <string>:1, in <lambda>(_cls, record_batch, fragment)
#
# KeyboardInterrupt:

# %%
for test_input_string in test_prompts:
    inputs = tokenizer(test_input_string, return_tensors="pt").to(DEVICE)
    # print(tokens[0])
    tokens = model.generate(**inputs, max_length=150, pad_token_id=tokenizer.eos_token_id)
    print("Without sampling: " + tokenizer.decode(tokens[0]))
    
    print("---------------")
    tokens = model.generate(**inputs, max_length=150, pad_token_id=tokenizer.eos_token_id, do_sample=True)
    print("With sampling   : " + tokenizer.decode(tokens[0]))
    
    print("\n===============")
# Out:
# Without sampling: Who is Barack Obama?-
#
#  is- is- is- is- is- a- is- a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is is is is is is is is is is is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is a is is is a is is a
# ---------------
# With sampling   : Who is Barack Obama?–<|endoftext|>
#
# ===============
# Without sampling: What is Carnegie Mellon University?- Carnegie Mell University- is university the of university the of. is university the of is university the of is
#
#  a of is
# <|endoftext|>
# ---------------
# With sampling   : What is Carnegie Mellon University?-aney-ul. is university is university is on campus of Mell
#  is community college is college the at ofacell community atellin
# -----END:ADDRESS
# :ame ""
# : is is of country is ,razil origin- is ,ox origin andox
#  is citynsylvaniaork country     is states states k     is     is- is- isicutis- is-consin- is- ,ut-- is-ic- isut- is-ian-     on is is      isde     is- is-l- isis in     is is of is- is-     isc- ais is of-ic is     is- is- isl-
#
# ===============
# Without sampling: Classify this restaurant review sentiment: 'The food was absolutely delicious but the service was extremely slow and the waiter seemed uninterested in helping us.':::::::::::::::::::::::::::::::::::::::::::::::
# ::::::]:::]:::]::]::]::]::]::]::]::]::]::]::]::]::]::]::]::]::]:]::]::]:]::]::]:]::]:]::]:]::]:]::]:]::]:]::]:
# ---------------
# With sampling   : Classify this restaurant review sentiment: 'The food was absolutely delicious but the service was extremely slow and the waiter seemed uninterested in helping us.' this no good as a
# attering. you't to the with for or because's ''t't just's good no you have it if't is. will love the... I this like very of so you the it not good be't you't a no the is you not do me what like a because't not because want't't to so the't for're't all to is for't't as in.'t it't be of be as the it not to me it me it I't to you don know what it if't't I't a-'t't it been! that there
#
# ===============
# Without sampling: Compare and contrast Carnegie Mellon University's Computer Science and Information Systems programs in terms of research focus and career outcomes.,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ---------------
# With sampling   : Compare and contrast Carnegie Mellon University's Computer Science and Information Systems programs in terms of research focus and career outcomes. based on:;This is a from of overview the and of at and:; in as; is complete the; to; the;: of is;; is of Answer C Answer
# diss : there no of at;
# :- is;
#  Answer C:
# ::diss
# Answer P
#  answer :
# :dissProblem Is product good free? ( )
# : is
# :obsHere is review product don waste time research
# : is
# : is
# ::: on left review this product not all a,s
# This what good is a that what to
# : there at
#
# : answer
#
# ===============
# Without sampling: Summarize in one sentence: Dr. Sarah Chen, lead scientist on the mission, called it 'the most significant discovery in the history of space exploration.' The finding suggests that Mars once had a much more hospitable environment with liquid water and possibly a thicker atmosphere. The agency plans to send a sample return mission within the next five years to bring these fossils back to Earth for more detailed analysis. This discovery has profound implications for our understanding of how life might develop throughout the universe.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# ---------------
# With sampling   : Summarize in one sentence: Dr. Sarah Chen, lead scientist on the mission, called it 'the most significant discovery in the history of space exploration.' The finding suggests that Mars once had a much more hospitable environment with liquid water and possibly a thicker atmosphere. The agency plans to send a sample return mission within the next five years to bring these fossils back to Earth for more detailed analysis. This discovery has profound implications for our understanding of how life might develop throughout the universe. it a of history a to the planet than living in Earth Earth. science is important we to the where the life we today must to if is of. are for.:ist a that not to?A is.:?.,..,ence
#
# ===============
